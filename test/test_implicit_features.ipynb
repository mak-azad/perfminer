# %%
import pandas as pd

# Path to your .jsonl file
file_path = '/home/ubuntu/python_perf.jsonl'

# Read the .jsonl file into a pandas DataFrame
df = pd.read_json(file_path, lines=True)
# Display the first few rows of the DataFrame to verify it's loaded correctly

# %%
gold_path = '/home/ubuntu/tmp/test/data/train.jsonl'
df_gold =  pd.read_json(gold_path, lines=True)

# %%
df_gold
# Out:
#        idx                                     commit_message  target
# 0     2452  added timestamp in logfile, refactored xmpp co...       1
# 1     3666  [PATCH] Remove percpufication of in_flight cou...       1
# 2     4076  [PATCH] gauge_field::FloatNOrder can now use _...       1
# 3     2120  f2fs: support revoking atomic written pages  f...       1
# 4     2774  Refactoring.  Be more efficient. Don't do recu...       0
# ...    ...                                                ...     ...
# 2171  1218  [IMP] improve contract usability  bzr revid: [...       0
# 2172  1964  xspress3: added another IOC shell driver start...       0
# 2173  2573  Merge pull request #25 from pedrovitti/patch-1...       0
# 2174  1112  Reducing Memory consumption on start by not re...       0
# 2175  1195  Simplified shell scripts to extract cpu, os, v...       0
#
# [2176 rows x 3 columns]

# %%
gold_perf = df_gold[df_gold['target'] == 1]
gold_perf
# Out:
#        idx                                     commit_message  target
# 0     2452  added timestamp in logfile, refactored xmpp co...       1
# 1     3666  [PATCH] Remove percpufication of in_flight cou...       1
# 2     4076  [PATCH] gauge_field::FloatNOrder can now use _...       1
# 3     2120  f2fs: support revoking atomic written pages  f...       1
# 5      925  sched: optimize select_best_cpu() where !sched...       1
# ...    ...                                                ...     ...
# 2164  4094  [PATCH] Move orb LUT in CUDA backend to textur...       1
# 2165  2391  Write the recent tracks file a bit later so th...       1
# 2168  2936       fixed circular import & improved performance       1
# 2169  4027  [PATCH] #1295 Refactored MX::setSub(IMatrix,IM...       1
# 2170  4101  [PATCH] modified to have 3c and 2c two electro...       1
#
# [1199 rows x 3 columns]

# %%
gold_nonperf = df_gold[df_gold['target'] == 0]
gold_nonperf
# Out:
#        idx                                     commit_message  target
# 4     2774  Refactoring.  Be more efficient. Don't do recu...       0
# 9       30  Added mind_values property to BeatDynamicProgr...       0
# 10    2139  This patch improves the readability of the pro...       0
# 11    1684  [en] improved TAG_QUESTIONS (#4853)  * [en] dr...       0
# 12     209  msm: wfd: Free ion handle on unmap  This commi...       0
# ...    ...                                                ...     ...
# 2171  1218  [IMP] improve contract usability  bzr revid: [...       0
# 2172  1964  xspress3: added another IOC shell driver start...       0
# 2173  2573  Merge pull request #25 from pedrovitti/patch-1...       0
# 2174  1112  Reducing Memory consumption on start by not re...       0
# 2175  1195  Simplified shell scripts to extract cpu, os, v...       0
#
# [976 rows x 3 columns]

# %%
perf_sample = gold_perf.sample(150)
nonperf_sample = gold_nonperf.sample(250)

# %%
perf_sample.to_json('perf_150',index=False)

# %%
# Combined list of all regex patterns extracted from the provided Python functions
combined_patterns = [
    r'slow.*fast',
    r'speed.*up',
    r'vector.*improve|vector.*improves|vector.*improving|vector.*improved|vectorize.*improve|vectorize.*improves|vectorize.*improving|vectorize.*improved|vectorzing.*improve|vectorzing.*improves|vectorzing.*improving|vectorzing.*improved|vectorized.*improve|vectorized.*improves|vectorized.*improving|vectorized.*improved',
    r'fast.*memory|faster.*memory',
    r'universal.*intrinsics|universal.*intrinsics',
    r'backend.*performance|backend.*performances',
    'speedup.*added|speedups.*added|speed-up.*added',
    'performance.*benefit|gain|increas|hit',
    r'more.*efficien',
    r'perf|optimiz|(speed.*up)|efficien|faster|benefit|gain|increas|hit|solution|patch|code',
    r'perf.*bug',
    r'large.*performance|large.*performances',
    r'better.*performance|better.*performances',
    r'patch.*improve|patch.*improves|patch.*improving|patch.*improved',
    r'accelerat',
    r'fixed.*performance|fixed.*performances',
    r'improv.*perf',
    r'optimize.*performance|optimize.*performances|optimizes.*performance|optimizes.*performances|optimized.*performance|optimized.*performances|optimizing.*performance|optimizing.*performances',
    r'(\d+)% fast',
    r'(\d+)x faster',
    r'increas.*perf',
    r'reduc.*overhead',
    r'optimiz',
    r'inefficien',
    r'memory.*optimiz',
    r'avoid.*overhead|reduce.*overhead',
    r'perf.*enhanc',
    r'perf.*gain',
    r'perf.*benefit',
    r'faster',
    r'perf.*improve|perf.*improves|perf.*improving|perf.*improved|perf.*improvement',
    'memory.*leak',
    r'performance fix',
    r'performance.*optimiz',
    r'performance.*inefficien',
    r'performance.*bottleneck',
    r'performance.*hit',
    r'performance.*(increas|throughput)',
    r'performance.*regression',
    r'patch',
    r'perf.*(issue|problem|regression)'
]

# Combining the patterns into a single regex pattern with the "or" (|) operator
regex_patterns = '|'.join(combined_patterns)

print("Combined Regex Pattern:")
print(regex_patterns)
# Out:
# Combined Regex Pattern:
# slow.*fast|speed.*up|vector.*improve|vector.*improves|vector.*improving|vector.*improved|vectorize.*improve|vectorize.*improves|vectorize.*improving|vectorize.*improved|vectorzing.*improve|vectorzing.*improves|vectorzing.*improving|vectorzing.*improved|vectorized.*improve|vectorized.*improves|vectorized.*improving|vectorized.*improved|fast.*memory|faster.*memory|universal.*intrinsics|universal.*intrinsics|backend.*performance|backend.*performances|speedup.*added|speedups.*added|speed-up.*added|performance.*benefit|gain|increas|hit|more.*efficien|perf|optimiz|(speed.*up)|efficien|faster|benefit|gain|increas|hit|solution|patch|code|perf.*bug|large.*performance|large.*performances|better.*performance|better.*performances|patch.*improve|patch.*improves|patch.*improving|patch.*improved|accelerat|fixed.*performance|fixed.*performances|improv.*perf|optimize.*performance|optimize.*performances|optimizes.*performance|optimizes.*performances|optimized.*performance|optimized.*performances|optimizing.*performance|optimizing.*performances|(\d+)% fast|(\d+)x faster|increas.*perf|reduc.*overhead|optimiz|inefficien|memory.*optimiz|avoid.*overhead|reduce.*overhead|perf.*enhanc|perf.*gain|perf.*benefit|faster|perf.*improve|perf.*improves|perf.*improving|perf.*improved|perf.*improvement|memory.*leak|performance fix|performance.*optimiz|performance.*inefficien|performance.*bottleneck|performance.*hit|performance.*(increas|throughput)|performance.*regression|patch|perf.*(issue|problem|regression)

# %%
import pandas as pd
import re

regex_df_gold = df_gold[df_gold['commit_message'].str.contains(regex_patterns, flags=re.IGNORECASE, na=False)]
# Out:
# /tmp/ipykernel_641225/3474666431.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   regex_df_gold = df_gold[df_gold['commit_message'].str.contains(regex_patterns, flags=re.IGNORECASE, na=False)]

# %%
regex_df_gold
regex_df_gold_perf = regex_df_gold[regex_df_gold['target'] == 1]

# %%
perf = regex_df_gold_perf.sample(150)
perf.to_json('perf_150.jsonl', orient='records', lines=True)

# %%
# regex_patterns=[] # all the regex patterns derived from the bi-gram 


# regex_patterns.append('slow.*fast')

# regex_patterns.append('see.*speedup|see.*speedups|see.*speed-up|seeing.*speedup|seeing.*speedups|seeing.*speed-up|sees.*speedup|sees.*speedups|sees.*speed-up|observe.*speedup|observe.*speedups|observe.*speed-up|observes.*speedup|observes.*speedups|observes.*speed-up|observed.*speedup|observed.*speedups|observed.*speed-up|observing.*speedup|observing.*speedups|observing.*speed-up')
# regex_patterns.append('vector.*improve|vector.*improves|vector.*improving|vector.*improved|vectorize.*improve|vectorize.*improves|vectorize.*improving|vectorize.*improved|vectorzing.*improve|vectorzing.*improves|vectorzing.*improving|vectorzing.*improved|vectorized.*improve|vectorized.*improves|vectorized.*improving|vectorized.*improved')
# regex_patterns.append('fast.*memory|faster.*memory')
# regex_patterns.append('universal.*intrinsics|universal.*intrinsics')
# regex_patterns.append('backend.*performance|backend.*performances')
# regex_patterns.append('speedup.*added|speedups.*added|speed-up.*added')
# #regex_patterns.append('this.*improves|this.*improved')
# #regex_patterns.append('fixed.*fast|fixes.*fast') #better to remove this seed as 
# regex_patterns.append('performance.*problem')
# regex_patterns.append('more.*efficient')
# #regex_patterns.append('secs.*time')
# regex_patterns.append('performance.*bug|performance.*fix|performance.*optimization|performance.*inefficien|performance.*bottleneck|performance.*improv|performance.*hit|performance.*increas|performance.*regression')
# regex_patterns.append('large.*performance|large.*performances')
# regex_patterns.append('better.*performance|better.*performances')
# #regex_patterns.append('(?<=\s)patch.*improv(?:e|es|ing|ed)')
# regex_patterns.append('patch.*improve|patch.*improves|patch.*improving|patch.*improved')
# #regex_patterns.append('(?<!\[)patch(?!]).*improve|(?<!\[)patch(?!]).*improves|(?<!\[)patch(?!]).*improving|(?<!\[)patch(?!]).*improved')
# regex_patterns.append('patch.*accelerate|patch.*accelerates|patch.*accelarated')
# regex_patterns.append('fixed.*performance|fixed.*performances')
# regex_patterns.append('improve.*performance|improve.*performances|improves.*performance|improves.*performances|improving.*performance|improving.*performances|improved.*performance|improved.*performances')
# regex_patterns.append('optimize.*performance|optimize.*performances|optimizes.*performance|optimizes.*performances|optimized.*performance|optimized.*performances|optimizing.*performance|optimizing.*performances')
# ############################

# %%
df_100 = df.sample(100)
df_100
# Out:
#                                               commit_url  \
# 10236  https://github.com/nipy/nibabel/commit/45f50e3...
# 5169   https://github.com/digitalfox/pydici/commit/7b...
# 741    https://github.com/FederatedAI/FATE/commit/33a...
# 5781   https://github.com/gnocchixyz/gnocchi/commit/d...
# 13342  https://github.com/saltstack/salt/commit/7158a...
# ...                                                  ...
# 11087  https://github.com/odoo/odoo/commit/57a34bb989...
# 4936   https://github.com/dask/distributed/commit/eb1...
# 2082   https://github.com/PyLabRobot/pylabrobot/commi...
# 8749   https://github.com/maxmind/MaxMind-DB-Reader-p...
# 8868   https://github.com/mesonbuild/meson/commit/499...
#
#                                           commit_message  \
# 10236  improve error handling, efficiency, and search...
# 5169   don't prefetch tags, it could overflow databas...
# 741    optimization mysql model restore  signed-off-b...
# 5781   speed up median aggregate  - find the position...
# 13342  add full /etc/lsb-release parsing and improve ...
# ...                                                  ...
# 11087  [imp] base: fields_view_get() benchmark  a tes...
# 4936   use `memoryview` in `unpack_frames` (#3980)  *...
# 2082          faster alg to check if resource is on deck
# 8749   remove extra map lookup from very hot code  th...
# 8868   compilers/cuda: don't use re for replacement  ...
#
#                      filename                commit_date  nloc  n_added_lines  \
# 10236        spatialimages.py  2015-09-22 12:45:21-04:00   465             22
# 5169                 learn.py  2019-10-23 18:12:47+02:00   345              3
# 741    mysql_model_storage.py  2020-06-28 11:08:56+08:00   112              4
# 5781             carbonara.py  2018-01-03 14:54:04+00:00   621             12
# 13342                 core.py  2011-11-30 18:40:33-08:00   231             25
# ...                       ...                        ...   ...            ...
# 11087           test_views.py  2021-06-11 13:47:54+00:00  2611             25
# 4936                 utils.py  2020-07-21 20:01:51-04:00    86              3
# 2082        liquid_handler.py  2022-11-22 12:23:00-05:00   819              4
# 8749               decoder.py  2019-09-24 07:59:07-07:00   130              4
# 8868                  cuda.py  2019-08-14 13:13:23-07:00   168              2
#
#        n_deleted_lines          modified_method loc_before    loc_after  \
# 10236                9                 is_image  [881:903]    [882:916]
# 5169                 4        extract_leads_tag  [156:173]    [156:172]
# 741                  5                  restore   [79:115]     [79:114]
# 5781                 1                   median  [150:151]    [150:162]
# 13342                4                  os_data  [184:261]    [184:282]
# ...                ...                      ...        ...          ...
# 11087                1    test_render_all_views  [122:141]  [3051:3068]
# 4936                 0            unpack_frames  [113:136]    [113:139]
# 2082                 1  _assert_resources_exist  [417:429]    [417:432]
# 8749                 2                   decode  [115:134]    [115:136]
# 8868                 3          _cook_link_args  [163:168]    [162:167]
#
#                                               src_before  \
# 10236  # emacs: -*- mode: python-mode; py-indent-offs...
# 5169   # coding: utf-8\n\n"""\nModule that handle pre...
# 741    #\n#  Copyright 2019 The FATE Authors. All Rig...
# 5781   # -*- encoding: utf-8 -*-\n#\n# Copyright © 20...
# 13342  '''\nThe static grains, these are the core, or...
# ...                                                  ...
# 11087  # -*- coding: utf-8 -*-\n# Part of Odoo. See L...
# 4936   import struct\nimport msgpack\n\nfrom ..utils ...
# 2082   """ Defines LiquidHandler class, the coordinat...
# 8749   """\nmaxminddb.decoder\n~~~~~~~~~~~~~~~~~\n\nT...
# 8868   # Copyright 2012-2017 The Meson development te...
#
#                                                src_after  \
# 10236  # emacs: -*- mode: python-mode; py-indent-offs...
# 5169   # coding: utf-8\n\n"""\nModule that handle pre...
# 741    #\n#  Copyright 2019 The FATE Authors. All Rig...
# 5781   # -*- encoding: utf-8 -*-\n#\n# Copyright © 20...
# 13342  '''\nThe static grains, these are the core, or...
# ...                                                  ...
# 11087  # -*- coding: utf-8 -*-\n# Part of Odoo. See L...
# 4936   import struct\nimport msgpack\n\nfrom ..utils ...
# 2082   """ Defines LiquidHandler class, the coordinat...
# 8749   """\nmaxminddb.decoder\n~~~~~~~~~~~~~~~~~\n\nT...
# 8868   # Copyright 2012-2017 The Meson development te...
#
#                                                     diff  func_no_tokens
# 10236  @@ -137,6 +137,7 @@ try:\n except NameError:  ...             148
# 5169   @@ -160,16 +160,15 @@ def extract_leads_tag(le...             118
# 741    @@ -88,15 +88,14 @@ class MysqlModelStorage(Mo...             247
# 5781   @@ -148,7 +148,18 @@ class GroupedTimeSeries(o...              14
# 13342  @@ -188,13 +188,31 @@ def os_data():\n     gra...             508
# ...                                                  ...             ...
# 11087  @@ -1,9 +1,10 @@\n # -*- coding: utf-8 -*-\n #...             134
# 4936   @@ -120,8 +120,11 @@ def unpack_frames(b):\n  ...              85
# 2082   @@ -425,7 +425,10 @@ class LiquidHandler:\n   ...              36
# 8749   @@ -125,13 +125,15 @@ class Decoder(object):  ...             107
# 8868   @@ -12,13 +12,12 @@\n # See the License for th...              23
#
# [100 rows x 14 columns]

# %%
import pandas as pd
import re

# Example DataFrame and regex patterns
#data = {'commit_message': ['fix bug #123', 'update README', 'feature add xyz', 'bug #123 fixed']}
#df = pd.DataFrame(data)

# List of regex patterns
#regex_patterns = ['bug #\\d+', 'fix']

# Combine regex patterns into a single pattern
#combined_regex = '|'.join(regex_patterns)

# Filter rows where 'commit_message' matches any of the regex patterns
# The ~ operator is used to get rows that do NOT match the pattern, remove it if you want rows that DO match
filtered_df = df_100[df_100['commit_message'].str.contains(regex_patterns, flags=re.IGNORECASE, na=False)]

print(filtered_df.head())
#filtered_df
# Out:
#                                               commit_url  \
# 10236  https://github.com/nipy/nibabel/commit/45f50e3...
# 5169   https://github.com/digitalfox/pydici/commit/7b...
# 741    https://github.com/FederatedAI/FATE/commit/33a...
# 5781   https://github.com/gnocchixyz/gnocchi/commit/d...
# 13342  https://github.com/saltstack/salt/commit/7158a...
#
#                                           commit_message  \
# 10236  improve error handling, efficiency, and search...
# 5169   don't prefetch tags, it could overflow databas...
# 741    optimization mysql model restore  signed-off-b...
# 5781   speed up median aggregate  - find the position...
# 13342  add full /etc/lsb-release parsing and improve ...
#
#                      filename                commit_date  nloc  n_added_lines  \
# 10236        spatialimages.py  2015-09-22 12:45:21-04:00   465             22
# 5169                 learn.py  2019-10-23 18:12:47+02:00   345              3
# 741    mysql_model_storage.py  2020-06-28 11:08:56+08:00   112              4
# 5781             carbonara.py  2018-01-03 14:54:04+00:00   621             12
# 13342                 core.py  2011-11-30 18:40:33-08:00   231             25
#
#        n_deleted_lines    modified_method loc_before  loc_after  \
# 10236                9           is_image  [881:903]  [882:916]
# 5169                 4  extract_leads_tag  [156:173]  [156:172]
# 741                  5            restore   [79:115]   [79:114]
# 5781                 1             median  [150:151]  [150:162]
# 13342                4            os_data  [184:261]  [184:282]
#
#                                               src_before  \
# 10236  # emacs: -*- mode: python-mode; py-indent-offs...
# 5169   # coding: utf-8\n\n"""\nModule that handle pre...
# 741    #\n#  Copyright 2019 The FATE Authors. All Rig...
# 5781   # -*- encoding: utf-8 -*-\n#\n# Copyright © 20...
# 13342  '''\nThe static grains, these are the core, or...
#
#                                                src_after  \
# 10236  # emacs: -*- mode: python-mode; py-indent-offs...
# 5169   # coding: utf-8\n\n"""\nModule that handle pre...
# 741    #\n#  Copyright 2019 The FATE Authors. All Rig...
# 5781   # -*- encoding: utf-8 -*-\n#\n# Copyright © 20...
# 13342  '''\nThe static grains, these are the core, or...
#
#                                                     diff  func_no_tokens
# 10236  @@ -137,6 +137,7 @@ try:\n except NameError:  ...             148
# 5169   @@ -160,16 +160,15 @@ def extract_leads_tag(le...             118
# 741    @@ -88,15 +88,14 @@ class MysqlModelStorage(Mo...             247
# 5781   @@ -148,7 +148,18 @@ class GroupedTimeSeries(o...              14
# 13342  @@ -188,13 +188,31 @@ def os_data():\n     gra...             508
# /tmp/ipykernel_641225/3192116783.py:16: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   filtered_df = df_100[df_100['commit_message'].str.contains(regex_patterns, flags=re.IGNORECASE, na=False)]

# %%
a = filtered_df.count()
b = df_100.count()
print(a)
print(b)
# Out:
# commit_url         60
# commit_message     60
# filename           60
# commit_date        60
# nloc               60
# n_added_lines      60
# n_deleted_lines    60
# modified_method    60
# loc_before         60
# loc_after          60
# src_before         60
# src_after          60
# diff               60
# func_no_tokens     60
# dtype: int64
# commit_url         100
# commit_message     100
# filename           100
# commit_date        100
# nloc               100
# n_added_lines      100
# n_deleted_lines    100
# modified_method    100
# loc_before         100
# loc_after          100
# src_before         100
# src_after          100
# diff               100
# func_no_tokens     100
# dtype: int64

# %%
import pandas as pd

# Load your DataFrame containing the idx column
df_new = pd.read_csv('/home/akazad/Downloads/out.csv')

# Assuming 'filtered_df' is already defined and loaded, and both DataFrames have the 'idx' column
if 'idx' in df_new.columns and 'idx' in filtered_df.columns:
    # Create a set of idx values from df_new for faster membership testing
    idx_set = set(df_new['idx'])

    # Filter filtered_df by checking if each idx is in the set of idx from df_new
    filtered_result_df = filtered_df[filtered_df['idx'].isin(idx_set)]

    # Display or analyze the filtered result
    #print(filtered_result_df)
else:
    print("Ensure both 'df_new' and 'filtered_df' have an 'idx' column.")

# %%
filtered_result_df.count()
# Out:
# idx               33
# commit_message    33
# dtype: int64

# %%
df_new.count()
# Out:
# idx               100
# commit_message    100
# pred_m            100
# pred_roberta      100
# color               0
# Unnamed: 5          9
# Unnamed: 6          0
# Unnamed: 7          4
# Unnamed: 8          4
# dtype: int64

# %%
# Sample 200 random lines from the DataFrame
sampled_df = filtered_df.sample(n=300, random_state=1)  # random_state for reproducibility

# Paths to the output files
output_jsonl_path = 'sampled_output_file.jsonl'
output_csv_path = 'sampled_output_file.csv'

# Write the sampled DataFrame to a new .jsonl file
sampled_df.to_json(output_jsonl_path, orient='records', lines=True)

# Write the sampled DataFrame to a new CSV file
sampled_df.to_csv(output_csv_path, index=False)

print("200 randomly selected lines have been saved to:")
print("JSONL file:", output_jsonl_path)
print("CSV file:", output_csv_path)
# Out:
# 200 randomly selected lines have been saved to:
# JSONL file: sampled_output_file.jsonl
# CSV file: sampled_output_file.csv
